# %% [markdown]
# ## Step 1 — Import the minimal libraries you need

# %%
import pandas as pd
# pandas is enough for this simple project
print('✓ pandas imported')
: 
,
: { 
: 
, 
: 
 },
: [
print('\nFirst 5 matches:')
print(matches[['date','home_team','away_team','home_score','away_score']].head())
: 
,
: { 
: 
, 
: 
 },
: [
3
]
: 
,
: { 
: 
, 
: 
 },
: [
,
,
,
